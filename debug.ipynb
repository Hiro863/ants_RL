# %%
import pickle
from pickle import Pickler, Unpickler
import numpy as np
import math
import os
np.set_printoptions(threshold=np.nan, linewidth=400)

# %%
from storage import TrainingStorage

td = TrainingStorage()
for i, (state, action, reward, turn) in enumerate(td.items()):
    current_ant, my_ants, my_hills, enemy_ants, enemy_hills, water, food = state
    print("List index", i, "Turn number", turn, "Reward", reward)
# Out:
# List index 0 Turn number 1 Reward 1
# List index 1 Turn number 2 Reward 1
# List index 2 Turn number 3 Reward 1
# List index 3 Turn number 4 Reward 1
# List index 4 Turn number 5 Reward 1
# List index 5 Turn number 6 Reward 1
# List index 6 Turn number 7 Reward 1
# List index 7 Turn number 8 Reward 1
# List index 8 Turn number 9 Reward 1
# List index 9 Turn number 10 Reward 1
# List index 10 Turn number 11 Reward 1
# List index 11 Turn number 12 Reward 1
# List index 12 Turn number 13 Reward 1
# List index 13 Turn number 14 Reward 1
# List index 14 Turn number 15 Reward 1
# List index 15 Turn number 16 Reward 1
# List index 16 Turn number 17 Reward 1
# List index 17 Turn number 18 Reward 1
# List index 18 Turn number 19 Reward 1
# List index 19 Turn number 20 Reward 1
# List index 20 Turn number 21 Reward 2
# List index 21 Turn number 22 Reward 2
# List index 22 Turn number 23 Reward 2
# List index 23 Turn number 23 Reward 2
# List index 24 Turn number 24 Reward 2
# ...

# %%
from __future__ import print_function
def render(state):
    for line in state:
        print()
        for cell in line:
            if cell == 0:
                print("-", end="")
            else:
                print(cell, end="")

# %%
ims = list(td.items())
idx = 45
print("Turn number", ims[idx][3])
print("Direction one hot", ims[idx][1])
render(ims[idx][0][2])
# Out:
# Turn number 46
# Direction one hot [0. 0. 0. 0. 1.]
#
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ...
